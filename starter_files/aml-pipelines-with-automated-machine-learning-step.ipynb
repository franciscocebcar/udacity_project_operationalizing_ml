# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.31.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-152341
# aml-quickstarts-152341
# southcentralus
# 3e42d11f-d64d-4173-af9b-12ecaa1030b3

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'ml-experiment-bankmarketing-with-sdk'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: ml-experiment-bankmarketing-with-sdk,
# Workspace: quick-starts-ws-152341)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "auto-ml-sdk"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    print("Creating the compute target")
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS12_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           min_nodes=1,
                                                           max_nodes=10)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)
    compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Creating the compute target
# Creating......
# SucceededProvisioning operation finished, operation "Succeeded"
# Succeeded..................
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "BankMarketing Dataset"
description_text = "Bank Marketing DataSet for Udacity Course 2"

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 60,
    "max_concurrent_iterations": 9,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [e1348267][724faeb9-1457-4872-8d58-bfddb840b855], (This step will run and generate new outputs)
# Submitted PipelineRun c5c90a48-c4c4-41f0-b47d-19f35305cfc6
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/c5c90a48-c4c4-41f0-b47d-19f35305cfc6?wsid=/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourcegroups/aml-quickstarts-152341/workspaces/quick-starts-ws-152341&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: c5c90a48-c4c4-41f0-b47d-19f35305cfc6
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/c5c90a48-c4c4-41f0-b47d-19f35305cfc6?wsid=/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourcegroups/aml-quickstarts-152341/workspaces/quick-starts-ws-152341&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# PipelineRun Status: Running
#
#
# StepRunId: 339ac137-1bc6-49e2-a77f-a9f1eb0efdb4
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/339ac137-1bc6-49e2-a77f-a9f1eb0efdb4?wsid=/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourcegroups/aml-quickstarts-152341/workspaces/quick-starts-ws-152341&tid=660b3398-b80e-49d2-bc5b-ac1dc93b5254
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '339ac137-1bc6-49e2-a77f-a9f1eb0efdb4', 'target': 'auto-ml-sdk', 'status': 'Completed', 'startTimeUtc': '2021-07-24T00:15:57.056907Z', 'endTimeUtc': '2021-07-24T00:47:16.931191Z', 'properties': {'ContentSnapshotId': '334920aa-1812-4787-9cf5-224b612450c6', 'StepType': 'AutoMLStep', 'azureml.moduleid': '724faeb9-1457-4872-8d58-bfddb840b855', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'e1348267', 'azureml.pipelinerunid': 'c5c90a48-c4c4-41f0-b47d-19f35305cfc6', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'auto-ml-sdk', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "3e42d11f-d64d-4173-af9b-12ecaa1030b3", "resource_group": "aml-quickstarts-152341", "workspace_name": "quick-starts-ws-152341", "region": "southcentralus", "compute_target": "auto-ml-sdk", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": false, "enable_code_generation": false, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "test_size": 0.0, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 9, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 60, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["LightGBM", "LogisticRegression", "RandomForest", "TensorFlowDNN", "AveragedPerceptronClassifier", "TensorFlowLinearClassifier", "KNN", "BernoulliNaiveBayes", "GradientBoosting", "SGD", "SVM", "LinearSVM", "XGBoostClassifier", "DecisionTree", "ExtremeRandomTrees", "MultinomialNaiveBayes"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "save_mlflow": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"3d84a6fd-d847-4342-a5df-61c409c0e9f4\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': '334920aa-1812-4787-9cf5-224b612450c6', 'SetupRunId': '339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_setup', 'SetupRunContainerId': 'dcid.339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_setup', 'ClientSdkVersi ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'c5c90a48-c4c4-41f0-b47d-19f35305cfc6', 'status': 'Completed', 'startTimeUtc': '2021-07-24T00:15:27.886209Z', 'endTimeUtc': '2021-07-24T00:48:31.310Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg152341.blob.core.windows.net/azureml/ExperimentRun/dcid.c5c90a48-c4c4-41f0-b47d-19f35305cfc6/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=%2FyrqJYLBf3f6BHjcFqdhU0XOa0UGfbDMjFsDoYWz3So%3D&st=2021-07-24T00%3A05%3A42Z&se=2021-07-24T08%3A15%3A42Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg152341.blob.core.windows.net/azureml/ExperimentRun/dcid.c5c90a48-c4c4-41f0-b47d-19f35305cfc6/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=BgmaXJibYu0V2HaR%2BSOHDIjZNw4eumI%2FVYPqWBatVHI%3D&st=2021-07-24T00%3A05%3A42Z&se=2021-07-24T08%3A15%3A42Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg152341.blob.core.windows.net/azureml/ExperimentRun/dcid.c5c90a48-c4c4-41f0-b47d-19f35305cfc6/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=PSuMOcnHrtI56iXkqmH2AM6lNeQtgGi8thOvtnmu%2FKA%3D&st=2021-07-24T00%3A05%3A42Z&se=2021-07-24T08%3A15%3A42Z&sp=r'}, 'submittedBy': 'ODL_User 152341'}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/339ac137-1bc6-49e2-a77f-a9f1eb0efdb4/metrics_data
# Downloaded azureml/339ac137-1bc6-49e2-a77f-a9f1eb0efdb4/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_10  \
# AUC_macro                                           [0.8726537333726037]
# f1_score_macro                                      [0.6555631753733615]
# balanced_accuracy                                   [0.7903405965023423]
# precision_score_micro                               [0.7790591805766313]
# accuracy                                            [0.7790591805766313]
# recall_score_micro                                  [0.7790591805766313]
# recall_score_weighted                               [0.7790591805766313]
# precision_score_weighted                            [0.8956127513797337]
# norm_macro_recall                                   [0.5806811930046847]
# average_precision_score_macro                       [0.7244229136609724]
# weighted_accuracy                                   [0.7762583101594147]
# matthews_correlation                               [0.40387615098348817]
# f1_score_micro                                      [0.7790591805766313]
# precision_score_macro                                 [0.64045223721575]
# AUC_weighted                                        [0.8726537333726038]
# log_loss                                            [0.5511028391925122]
# AUC_micro                                           [0.8590181011833351]
# average_precision_score_weighted                    [0.9231696509392513]
# f1_score_weighted                                   [0.8156134973727334]
# recall_score_macro                                  [0.7903405965023423]
# average_precision_score_micro                       [0.8403065371731576]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_11  \
# AUC_macro                                           [0.8997637293529462]
# f1_score_macro                                      [0.6261450632397377]
# balanced_accuracy                                   [0.8240256035506357]
# precision_score_micro                                [0.723216995447648]
# accuracy                                             [0.723216995447648]
# recall_score_micro                                   [0.723216995447648]
# recall_score_weighted                                [0.723216995447648]
# precision_score_weighted                             [0.912252594533025]
# norm_macro_recall                                   [0.6480512071012714]
# average_precision_score_macro                       [0.7437864844207194]
# weighted_accuracy                                    [0.698188944882386]
# matthews_correlation                                  [0.42136791669138]
# f1_score_micro                                       [0.723216995447648]
# precision_score_macro                               [0.6369883423341018]
# AUC_weighted                                        [0.8997637293529462]
# log_loss                                            [0.4726622106507942]
# AUC_micro                                            [0.864275802993914]
# average_precision_score_weighted                    [0.9319706808684928]
# f1_score_weighted                                   [0.7739788515992531]
# recall_score_macro                                  [0.8240256035506357]
# average_precision_score_micro                       [0.8770984524954262]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_15  \
# AUC_macro                                           [0.8873111270415506]
# f1_score_macro                                      [0.4703423886834914]
# balanced_accuracy                                                  [0.5]
# precision_score_micro                               [0.8880121396054628]
# accuracy                                            [0.8880121396054628]
# recall_score_micro                                  [0.8880121396054628]
# recall_score_weighted                               [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# norm_macro_recall                                                  [0.0]
# average_precision_score_macro                       [0.6931414766170443]
# weighted_accuracy                                   [0.9843450583187134]
# matthews_correlation                                               [0.0]
# f1_score_micro                                      [0.8880121396054628]
# precision_score_macro                               [0.4440060698027314]
# AUC_weighted                                        [0.8873111270415506]
# log_loss                                            [0.2515250157844837]
# AUC_micro                                           [0.9650456731931629]
# average_precision_score_weighted                    [0.9186680605732366]
# f1_score_weighted                                   [0.8353395018439429]
# recall_score_macro                                                 [0.5]
# average_precision_score_micro                       [0.9648339527270738]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_8  \
# AUC_macro                                          [0.8870730966366396]
# f1_score_macro                                     [0.4703423886834914]
# balanced_accuracy                                                 [0.5]
# precision_score_micro                              [0.8880121396054628]
# accuracy                                           [0.8880121396054628]
# recall_score_micro                                 [0.8880121396054628]
# recall_score_weighted                              [0.8880121396054628]
# precision_score_weighted                            [0.788565560086672]
# norm_macro_recall                                                 [0.0]
# average_precision_score_macro                      [0.7371256040024007]
# weighted_accuracy                                  [0.9843450583187134]
# matthews_correlation                                              [0.0]
# f1_score_micro                                     [0.8880121396054628]
# precision_score_macro                              [0.4440060698027314]
# AUC_weighted                                       [0.8870730966366396]
# log_loss                                           [0.2766001134522425]
# AUC_micro                                          [0.9649983305739832]
# average_precision_score_weighted                   [0.9273057785924051]
# f1_score_weighted                                  [0.8353395018439429]
# recall_score_macro                                                [0.5]
# average_precision_score_micro                      [0.9646022004237172]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_13  \
# AUC_macro                                           [0.9308878256246677]
# f1_score_macro                                      [0.6650154684677185]
# balanced_accuracy                                   [0.6227454260188535]
# precision_score_micro                               [0.9062215477996965]
# accuracy                                            [0.9062215477996965]
# recall_score_micro                                  [0.9062215477996965]
# recall_score_weighted                               [0.9062215477996965]
# precision_score_weighted                            [0.8929725418691179]
# norm_macro_recall                                  [0.24549085203770704]
# average_precision_score_macro                       [0.7985126174047921]
# weighted_accuracy                                   [0.9766010009385309]
# matthews_correlation                                [0.3976739324324451]
# f1_score_micro                                      [0.9062215477996965]
# precision_score_macro                                [0.822098675416211]
# AUC_weighted                                        [0.9308878256246675]
# log_loss                                           [0.33655623031442766]
# AUC_micro                                           [0.9758990146932517]
# average_precision_score_weighted                     [0.947605275820125]
# f1_score_weighted                                    [0.885603431576398]
# recall_score_macro                                  [0.6227454260188535]
# average_precision_score_micro                       [0.9766643355999638]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_1  \
# AUC_macro                                          [0.9392346349984347]
# f1_score_macro                                     [0.7416848907681176]
# balanced_accuracy                                  [0.7191727470931578]
# precision_score_micro                              [0.9071320182094081]
# accuracy                                           [0.9071320182094081]
# recall_score_micro                                 [0.9071320182094081]
# recall_score_weighted                              [0.9071320182094081]
# precision_score_weighted                           [0.8991976076061607]
# norm_macro_recall                                 [0.43834549418631563]
# average_precision_score_macro                      [0.8065229883244922]
# weighted_accuracy                                  [0.9537972210153172]
# matthews_correlation                                [0.488678780261868]
# f1_score_micro                                     [0.9071320182094081]
# precision_score_macro                              [0.7723958081530135]
# AUC_weighted                                       [0.9392346349984347]
# log_loss                                          [0.18743634958563793]
# AUC_micro                                          [0.9781770788959222]
# average_precision_score_weighted                   [0.9505970434373063]
# f1_score_weighted                                  [0.9021127651963996]
# recall_score_macro                                 [0.7191727470931578]
# average_precision_score_micro                      [0.9791945367231853]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_18  \
# AUC_macro                                           [0.8828117040568902]
# f1_score_macro                                      [0.6387201304325674]
# balanced_accuracy                                   [0.7910505198695186]
# precision_score_micro                               [0.7550834597875569]
# accuracy                                            [0.7550834597875569]
# recall_score_micro                                  [0.7550834597875569]
# recall_score_weighted                               [0.7550834597875569]
# precision_score_weighted                            [0.8969846517001221]
# norm_macro_recall                                   [0.5821010397390372]
# average_precision_score_macro                       [0.7347120403610334]
# weighted_accuracy                                   [0.7461538116617192]
# matthews_correlation                                [0.3933595632669977]
# f1_score_micro                                      [0.7550834597875569]
# precision_score_macro                               [0.6329079794145114]
# AUC_weighted                                        [0.8828117040568904]
# log_loss                                            [0.5626791053495513]
# AUC_micro                                           [0.8527530331743732]
# average_precision_score_weighted                    [0.9279110383556709]
# f1_score_weighted                                   [0.7978329823901654]
# recall_score_macro                                  [0.7910505198695186]
# average_precision_score_micro                       [0.8553640109030733]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_5  \
# AUC_macro                                           [0.898923676523163]
# f1_score_macro                                     [0.6263947343363969]
# balanced_accuracy                                  [0.5942781010175104]
# precision_score_micro                              [0.8977238239757208]
# accuracy                                           [0.8977238239757208]
# recall_score_micro                                 [0.8977238239757208]
# recall_score_weighted                              [0.8977238239757208]
# precision_score_weighted                            [0.877014103638037]
# norm_macro_recall                                 [0.18855620203502088]
# average_precision_score_macro                      [0.7324050344679707]
# weighted_accuracy                                  [0.9730611889183236]
# matthews_correlation                              [0.31999379338174755]
# f1_score_micro                                     [0.8977238239757208]
# precision_score_macro                               [0.771526544069397]
# AUC_weighted                                       [0.8989236765231631]
# log_loss                                          [0.23592513528639933]
# AUC_micro                                          [0.9677031230931125]
# average_precision_score_weighted                    [0.929285703050008]
# f1_score_weighted                                  [0.8734704046383025]
# recall_score_macro                                 [0.5942781010175104]
# average_precision_score_micro                      [0.9685461159410444]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_12  \
# AUC_macro                                            [0.871565462066104]
# f1_score_macro                                      [0.6355706767158582]
# balanced_accuracy                                   [0.7591391635037334]
# precision_score_micro                               [0.7657056145675265]
# accuracy                                            [0.7657056145675265]
# recall_score_micro                                  [0.7657056145675265]
# recall_score_weighted                               [0.7657056145675265]
# precision_score_weighted                            [0.8854834349263523]
# norm_macro_recall                                   [0.5182783270074669]
# average_precision_score_macro                       [0.7356625637957661]
# weighted_accuracy                                   [0.7673358867471705]
# matthews_correlation                                [0.3600270814434999]
# f1_score_micro                                      [0.7657056145675264]
# precision_score_macro                               [0.6250481571563545]
# AUC_weighted                                         [0.871565462066104]
# log_loss                                            [0.5931768182377417]
# AUC_micro                                            [0.854060942108911]
# average_precision_score_weighted                    [0.9264584971876755]
# f1_score_weighted                                   [0.8045676478111939]
# recall_score_macro                                  [0.7591391635037334]
# average_precision_score_micro                       [0.8472436809659563]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_41  ...  \
# AUC_macro                                           [0.9386150149949892]  ...
# f1_score_macro                                      [0.7652153147826823]  ...
# balanced_accuracy                                   [0.7552213868003341]  ...
# precision_score_micro                               [0.9101669195751139]  ...
# accuracy                                            [0.9101669195751139]  ...
# recall_score_micro                                  [0.9101669195751139]  ...
# recall_score_weighted                               [0.9101669195751139]  ...
# precision_score_weighted                            [0.9069013800026041]  ...
# norm_macro_recall                                   [0.5104427736006683]  ...
# average_precision_score_macro                       [0.8022470859728432]  ...
# weighted_accuracy                                   [0.9486357041573478]  ...
# matthews_correlation                                [0.5312309488431649]  ...
# f1_score_micro                                      [0.9101669195751139]  ...
# precision_score_macro                               [0.7764328692696766]  ...
# AUC_weighted                                        [0.9386150149949893]  ...
# log_loss                                            [0.2320866790463207]  ...
# AUC_micro                                           [0.9773262012383687]  ...
# average_precision_score_weighted                    [0.9494719102600525]  ...
# f1_score_weighted                                   [0.9083753199793789]  ...
# recall_score_macro                                  [0.7552213868003341]  ...
# average_precision_score_micro                       [0.9783025231706844]  ...
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_49  \
# AUC_macro                                           [0.9436970104492569]
# f1_score_macro                                      [0.7727908552875257]
# balanced_accuracy                                   [0.7567713629972936]
# precision_score_micro                               [0.9150227617602428]
# accuracy                                            [0.9150227617602428]
# recall_score_micro                                  [0.9150227617602428]
# recall_score_weighted                               [0.9150227617602428]
# precision_score_weighted                            [0.9103936567676629]
# norm_macro_recall                                   [0.5135427259945873]
# average_precision_score_macro                       [0.8146358499907052]
# weighted_accuracy                                   [0.9543123034451771]
# matthews_correlation                                [0.5476651690313282]
# f1_score_micro                                      [0.9150227617602428]
# precision_score_macro                               [0.7920274421073921]
# AUC_weighted                                         [0.943697010449257]
# log_loss                                           [0.18212320288728928]
# AUC_micro                                           [0.9792477220969833]
# average_precision_score_weighted                    [0.9529012007897981]
# f1_score_weighted                                    [0.912294877094483]
# recall_score_macro                                  [0.7567713629972936]
# average_precision_score_micro                       [0.9802204735535665]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_45  \
# AUC_macro                                           [0.9454160160193537]
# f1_score_macro                                      [0.7654131134837717]
# balanced_accuracy                                    [0.746443899845697]
# precision_score_micro                                 [0.91350531107739]
# accuracy                                              [0.91350531107739]
# recall_score_micro                                    [0.91350531107739]
# recall_score_weighted                                 [0.91350531107739]
# precision_score_weighted                            [0.9078455714866506]
# norm_macro_recall                                  [0.49288779969139407]
# average_precision_score_macro                       [0.8168232718023524]
# weighted_accuracy                                   [0.9549821405515084]
# matthews_correlation                                [0.5339559652724806]
# f1_score_micro                                        [0.91350531107739]
# precision_score_macro                               [0.7892229966217245]
# AUC_weighted                                        [0.9454160160193535]
# log_loss                                           [0.17884045029542522]
# AUC_micro                                            [0.979779635765783]
# average_precision_score_weighted                     [0.953579804067766]
# f1_score_weighted                                   [0.9100547289333064]
# recall_score_macro                                   [0.746443899845697]
# average_precision_score_micro                       [0.9807268804681095]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_38  \
# AUC_macro                                           [0.9280115477162973]
# f1_score_macro                                      [0.7305771344394344]
# balanced_accuracy                                   [0.7078199934425865]
# precision_score_micro                                [0.903793626707132]
# accuracy                                             [0.903793626707132]
# recall_score_micro                                   [0.903793626707132]
# recall_score_weighted                                [0.903793626707132]
# precision_score_weighted                            [0.8949790242065471]
# norm_macro_recall                                    [0.415639986885173]
# average_precision_score_macro                       [0.7844737904006336]
# weighted_accuracy                                   [0.9524485788496345]
# matthews_correlation                               [0.46703896869001327]
# f1_score_micro                                       [0.903793626707132]
# precision_score_macro                               [0.7623970324771612]
# AUC_weighted                                        [0.9280115477162973]
# log_loss                                            [0.2047043114285382]
# AUC_micro                                           [0.9748888853069786]
# average_precision_score_weighted                    [0.9438957221872337]
# f1_score_weighted                                   [0.8982208023911766]
# recall_score_macro                                  [0.7078199934425865]
# average_precision_score_micro                       [0.9751712631617686]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_53  \
# AUC_macro                                           [0.9366663147150953]
# f1_score_macro                                      [0.7421454831932772]
# balanced_accuracy                                   [0.7146191420902589]
# precision_score_micro                               [0.9095599393019727]
# accuracy                                            [0.9095599393019727]
# recall_score_micro                                  [0.9095599393019727]
# recall_score_weighted                               [0.9095599393019727]
# precision_score_weighted                            [0.9005324142771018]
# norm_macro_recall                                   [0.4292382841805178]
# average_precision_score_macro                       [0.7986233728068056]
# weighted_accuracy                                   [0.9579584661902998]
# matthews_correlation                                [0.4926894414924297]
# f1_score_micro                                      [0.9095599393019727]
# precision_score_macro                               [0.7827600597434545]
# AUC_weighted                                        [0.9366663147150953]
# log_loss                                            [0.1902415116275064]
# AUC_micro                                           [0.9772814375945528]
# average_precision_score_weighted                     [0.948595276751151]
# f1_score_weighted                                    [0.903380422654646]
# recall_score_macro                                  [0.7146191420902589]
# average_precision_score_micro                       [0.9783771487826396]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_61  \
# AUC_macro                                           [0.9332639618262211]
# f1_score_macro                                      [0.7004417301274921]
# balanced_accuracy                                   [0.6599661570778388]
# precision_score_micro                               [0.9071320182094081]
# accuracy                                            [0.9071320182094081]
# recall_score_micro                                  [0.9071320182094081]
# recall_score_weighted                               [0.9071320182094081]
# precision_score_weighted                            [0.8931964859242526]
# norm_macro_recall                                   [0.3199323141556776]
# average_precision_score_macro                       [0.7907342980092962]
# weighted_accuracy                                   [0.9684966158049594]
# matthews_correlation                               [0.43388718529073544]
# f1_score_micro                                      [0.9071320182094081]
# precision_score_macro                               [0.7942154968877442]
# AUC_weighted                                        [0.9332639618262212]
# log_loss                                            [0.2008261837552562]
# AUC_micro                                            [0.976270755570702]
# average_precision_score_weighted                    [0.9464284926554556]
# f1_score_weighted                                   [0.8935389411707728]
# recall_score_macro                                  [0.6599661570778388]
# average_precision_score_micro                       [0.9773955308646439]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_57  \
# AUC_macro                                           [0.9410610784166624]
# f1_score_macro                                      [0.7555577536536513]
# balanced_accuracy                                   [0.7305375411922267]
# precision_score_micro                               [0.9125948406676783]
# accuracy                                            [0.9125948406676783]
# recall_score_micro                                  [0.9125948406676783]
# recall_score_weighted                               [0.9125948406676783]
# precision_score_weighted                            [0.9050462943185681]
# norm_macro_recall                                   [0.4610750823844534]
# average_precision_score_macro                       [0.8039884298271789]
# weighted_accuracy                                   [0.9577947435608085]
# matthews_correlation                                 [0.517268841395156]
# f1_score_micro                                      [0.9125948406676783]
# precision_score_macro                               [0.7901556216121699]
# AUC_weighted                                        [0.9410610784166624]
# log_loss                                           [0.18434965591562977]
# AUC_micro                                            [0.978347291269938]
# average_precision_score_weighted                    [0.9502446385364754]
# f1_score_weighted                                   [0.9076000980288377]
# recall_score_macro                                  [0.7305375411922267]
# average_precision_score_micro                       [0.9793681562359651]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_55  \
# AUC_macro                                            [0.943455275290962]
# f1_score_macro                                      [0.7604744421886932]
# balanced_accuracy                                   [0.7418662139458032]
# precision_score_micro                               [0.9116843702579667]
# accuracy                                            [0.9116843702579667]
# recall_score_micro                                  [0.9116843702579667]
# recall_score_weighted                               [0.9116843702579667]
# precision_score_weighted                            [0.9058629036989744]
# norm_macro_recall                                   [0.4837324278916064]
# average_precision_score_macro                       [0.8129298237558922]
# weighted_accuracy                                   [0.9538456249668733]
# matthews_correlation                                [0.5240377538867557]
# f1_score_micro                                      [0.9116843702579667]
# precision_score_macro                               [0.7838506906551768]
# AUC_weighted                                        [0.9434552752909621]
# log_loss                                            [0.1808357941970585]
# AUC_micro                                           [0.9791669449043361]
# average_precision_score_weighted                    [0.9525226776464265]
# f1_score_weighted                                   [0.9081611442792707]
# recall_score_macro                                  [0.7418662139458032]
# average_precision_score_micro                       [0.9801649493283194]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_63  \
# AUC_macro                                           [0.9431639890561585]
# f1_score_macro                                      [0.7556257326342737]
# balanced_accuracy                                   [0.7344196596443067]
# precision_score_micro                               [0.9110773899848255]
# accuracy                                            [0.9110773899848255]
# recall_score_micro                                  [0.9110773899848255]
# recall_score_weighted                               [0.9110773899848255]
# precision_score_weighted                            [0.9043597378614506]
# norm_macro_recall                                  [0.46883931928861333]
# average_precision_score_macro                       [0.8091251563962392]
# weighted_accuracy                                   [0.9549367259176257]
# matthews_correlation                                [0.5154931126518896]
# f1_score_micro                                      [0.9110773899848255]
# precision_score_macro                               [0.7833946922313813]
# AUC_weighted                                        [0.9431639890561585]
# log_loss                                            [0.1812226247428256]
# AUC_micro                                            [0.979001798374785]
# average_precision_score_weighted                     [0.951637686800854]
# f1_score_weighted                                   [0.9068775925449892]
# recall_score_macro                                  [0.7344196596443067]
# average_precision_score_micro                       [0.9800045982236802]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_56  \
# AUC_macro                                           [0.9386659553540171]
# f1_score_macro                                      [0.7527946582639358]
# balanced_accuracy                                   [0.7315387507942065]
# precision_score_micro                               [0.9101669195751139]
# accuracy                                            [0.9101669195751139]
# recall_score_micro                                  [0.9101669195751139]
# recall_score_weighted                               [0.9101669195751139]
# precision_score_weighted                            [0.9032678090477879]
# norm_macro_recall                                    [0.463077501588413]
# average_precision_score_macro                       [0.8060569922975342]
# weighted_accuracy                                   [0.9545154620732047]
# matthews_correlation                                [0.5099293232210654]
# f1_score_micro                                      [0.9101669195751139]
# precision_score_macro                               [0.7807606866979783]
# AUC_weighted                                         [0.938665955354017]
# log_loss                                           [0.18736428190260807]
# AUC_micro                                           [0.9779044443574552]
# average_precision_score_weighted                     [0.950451431948863]
# f1_score_weighted                                   [0.9058569907754163]
# recall_score_macro                                  [0.7315387507942065]
# average_precision_score_micro                       [0.9789553831770621]
#
#                                  339ac137-1bc6-49e2-a77f-a9f1eb0efdb4_51
# AUC_macro                                           [0.9427893458702188]
# f1_score_macro                                      [0.7606299838431283]
# balanced_accuracy                                   [0.7389973455442005]
# precision_score_micro                               [0.9128983308042489]
# accuracy                                            [0.9128983308042489]
# recall_score_micro                                  [0.9128983308042489]
# recall_score_weighted                               [0.9128983308042489]
# precision_score_weighted                            [0.9063760334698269]
# norm_macro_recall                                    [0.477994691088401]
# average_precision_score_macro                       [0.8106794637537813]
# weighted_accuracy                                   [0.9560732415022609]
# matthews_correlation                                 [0.525559527545843]
# f1_score_micro                                      [0.9128983308042489]
# precision_score_macro                               [0.7889287497788616]
# AUC_weighted                                        [0.9427893458702187]
# log_loss                                           [0.18133736687299454]
# AUC_micro                                           [0.9789361266092691]
# average_precision_score_weighted                    [0.9519361429177335]
# f1_score_weighted                                   [0.9087845360423618]
# recall_score_macro                                  [0.7389973455442005]
# average_precision_score_micro                         [0.97993494943252]
#
# [21 rows x 69 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/339ac137-1bc6-49e2-a77f-a9f1eb0efdb4/model_data
# Downloaded azureml/339ac137-1bc6-49e2-a77f-a9f1eb0efdb4/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=False, enable_feature_sweeping=True, feature_sweeping_config={}, feature_sweeping_timeout=86400, featurization_config=None, force_text_dnn=False, is_cross_validation=False, is_onnx_compatible=False, observer=None, task='classification', working_dir='/m...
# ), random_state=None, reg_alpha=0.42105263157894735, reg_lambda=0.3684210526315789, subsample=0.09947368421052633))], verbose=False))], flatten_transform=None, weights=[0.13333333333333333, 0.2, 0.13333333333333333, 0.06666666666666667, 0.06666666666666667, 0.13333333333333333, 0.13333333333333333, 0.06666666666666667, 0.06666666666666667]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(
#       task='classification',
#       is_onnx_compatible=False,
#       enable_feature_sweeping=True,
#       enable_dnn=False,
#       force_text_dnn=False,
#       feature_sweeping_timeout=86400,
#       featurization_config=None,
#       is_cross_validation=False,
#       feature_sweeping_config={}
#   )),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(
#       estimators=[('43', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.4, gamma=0, max_depth=9, max_leaves=15, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=2.5, reg_lambda=2.5, subsample=0.9, tree_method='auto'))],
#                verbose=False)), ('32', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.001, gamma=0.01, max_depth=6, max_leaves=0, n_estimators=200, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_featu...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=2.5, reg_lambda=2.3958333333333335, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('45', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=1, eta=0.2, gamma=0, max_depth=7, max_leaves=3, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=1...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0.7291666666666667, reg_lambda=0.7291666666666667, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('47', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.7, eta=0.3, gamma=0, grow_policy='lossguide', max_bin=255, max_depth=9, max_leaves=0, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           da...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0, reg_lambda=1.875, subsample=1, tree_method='hist'))],
#                verbose=False)), ('0', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(min_data_in_leaf=20, n_jobs=1, problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_categorical=0,
#           dataset_categoricals=None,
#           pipeline_categoricals=None,
#           dataset_y_std=None,
#           dataset_uid=None,
#           subsamplin...
#           subsampling_schedule='hyperband_clip',
#           cost_mode_param=None,
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None))],
#                verbose=False)), ('37', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.9, eta=0.001, gamma=5, max_depth=6, max_leaves=15, n_estimators=100, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_featu...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.875, reg_lambda=1.9791666666666667, subsample=0.6, tree_method='auto'))],
#                verbose=False)), ('23', Pipeline(memory=None,
#                steps=[('sparsenormalizer', Normalizer(copy=True, norm='max')),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.8, eta=0.3, gamma=1, max_depth=8, max_leaves=3, n_estimators=600, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(
#           dataset_samples=29655,
#           dataset_features=132,
#           dataset_classes=2,
#           dataset_num_c...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=0.625, reg_lambda=2.3958333333333335, subsample=0.8, tree_method='auto'))],
#                verbose=False)), ('48', Pipeline(memory=None,
#                steps=[('standardscalerwrapper',
#                        StandardScalerWrapper(
#           copy=True,
#           with_mean=False,
#           with_std=False
#       )),
#                       ('xgboostclassifier',
#                        XGBoostClassifier(booster='gbtree', colsample_bytree=0.9, eta=0.01, gamma=0, grow_policy='lossguide', max_bin=1023, max_depth=5, max_leaves=0, n_estimators=800, n_jobs=1, objective='reg:logistic', problem_info=ProblemInfo(...
#           iteration_timeout_mode=0,
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=0, reg_alpha=1.9791666666666667, reg_lambda=0, subsample=0.5, tree_method='hist'))],
#                verbose=False)), ('25', Pipeline(memory=None,
#                steps=[('maxabsscaler', MaxAbsScaler(copy=True)),
#                       ('lightgbmclassifier',
#                        LightGBMClassifier(boosting_type='gbdt', colsample_bytree=0.3966666666666666, learning_rate=0.05263631578947369, max_bin=80, max_depth=10, min_child_weight=5, min_data_in_leaf=0.06896862068965517, min_split_gain=0, n_estimators=10, n_jobs=1, num_leaves=149, problem_info...
#           iteration_timeout_param=None,
#           feature_column_names=None,
#           label_column_name=None,
#           weight_column_name=None,
#           cv_split_column_names=None,
#           enable_streaming=None,
#           timeseries_param_dict=None,
#           gpu_training_param_dict={'processing_unit_type': 'cpu'}
#       ), random_state=None, reg_alpha=0.42105263157894735, reg_lambda=0.3684210526315789, subsample=0.09947368421052633))],
#                verbose=False))],
#       weights=[0.13333333333333333, 0.2, 0.13333333333333333, 0.06666666666666667, 0.06666666666666667, 0.13333333333333333, 0.13333333333333333, 0.06666666666666667, 0.06666666666666667],
#       flatten_transform=None,
#       classification_labels=array([0, 1])
#   ))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530a" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530alevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow0_col0" class="data row0 col0" >28869</td>
#                         <td id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow0_col1" class="data row0 col1" >389</td>
#             </tr>
#             <tr>
#                         <th id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530alevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow1_col0" class="data row1 col0" >1062</td>
#                         <td id="T_a72b3f42_ec22_11eb_8e5f_dfa00540530arow1_col1" class="data row1 col1" >2630</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: 8983b8f7-604a-4ea3-9797-a96576939afc,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/3e42d11f-d64d-4173-af9b-12ecaa1030b3/resourceGroups/aml-quickstarts-152341/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-152341/PipelineRuns/PipelineSubmit/8983b8f7-604a-4ea3-9797-a96576939afc)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  cf897e3f-b9ab-4817-885e-3c18fad1c7aa

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
